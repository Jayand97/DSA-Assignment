# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayand97/DSA-Assignment/blob/main/Assignment_4_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Assignment on Statatics Using Student Performance.csv**

# %%
import pandas as pd

# %%
data1 = pd.read_csv('/content/Students_Performance.csv')
data1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#  Find out how many males and females participated in the test
gender_cnt = data1['gender'].value_counts()
gender_cnt
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# Parental level of education
peducation_level = data1['parental level of education'].value_counts()
peducation_level
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
# Who scores the most on average for math, reading, and writing based on:

# Gender
avg_s_gender = data1.groupby('gender')['math score', 'reading score', 'writing score'].mean()
avg_s_gender
# Out:
# <ipython-input-12-f8072442d2fb>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_s_gender = data1.groupby('gender')['math score', 'reading score', 'writing score'].mean()
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
# Test preparation course
prep_c_avg = data1.groupby('test preparation course')['math score', 'reading score', 'writing score'].mean()
prep_c_avg
# Out:
# <ipython-input-13-1d6f462c23dd>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   prep_c_avg = data1.groupby('test preparation course')['math score', 'reading score', 'writing score'].mean()
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
# Scoring variation for math, reading, and writing based on:
# Gender
score_var_by_gender = data1.groupby('gender')['math score', 'reading score', 'writing score'].std()
score_var_by_gender
# Out:
# <ipython-input-15-34197cf34fbf>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   score_var_by_gender = data1.groupby('gender')['math score', 'reading score', 'writing score'].std()
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %%
# Test preparation course
score_var_by_pcourse = data1.groupby('test preparation course')['math score', 'reading score', 'writing score'].std()
score_var_by_pcourse
# Out:
# <ipython-input-16-878108b5cf4a>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   score_var_by_pcourse = data1.groupby('test preparation course')['math score', 'reading score', 'writing score'].std()
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %%
# Give bonus points to the top 25% of students based on their math score

# Sort maths score in descending order
smath_scores = data1['math score'].sort_values(ascending=False)
smath_scores
# Out:
# 999    170
# 996    170
# 515    170
# 517    170
# 516    170
#       ...
# 2       18
# 51      13
# 3       11
# 1        8
# 0        0
# Name: math score, Length: 1000, dtype: int64

# %%
# Top scores of 25% total students
top_25= smath_scores.iloc[:int(0.25 * len(smath_scores))]
top_25
# Out:
# 999    170
# 996    170
# 515    170
# 517    170
# 516    170
#       ...
# 856    147
# 855    147
# 854    147
# 853    147
# 852    147
# Name: math score, Length: 250, dtype: int64

# %%
# Add 10 bonous point to top 25% scores
data1.loc[top_25, 'math score'] += 10
updata1=data1.loc[top_25, 'math score'] + 10
updata1
# Out:
# 999    180
# 996    180
# 515    180
# 517    180
# 516    180
#       ...
# 856    157
# 855    157
# 854    157
# 853    157
# 852    157
# Name: math score, Length: 250, dtype: int64

# %% [markdown]
# # **Case Study on Testing on Hypothesis Using Sales_add.csv**

# %%
from scipy.stats import ttest_rel, chi2_contingency

# %%
data= pd.read_csv('/content/Sales_add.csv')
data
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %%
data2 = data.rename(columns={'Sales_before_digital_add(in $)':'Sales_Before_DM','Sales_After_digital_add(in $)':'Sales_After_DM'})
data2
# Out:
#        Month      Region      Manager  Sales_Before_DM  Sales_After_DM
# 0    Month-1  Region - A  Manager - A           132921          270390
# 1    Month-2  Region - A  Manager - C           149559          223334
# 2    Month-3  Region - B  Manager - A           146278          244243
# 3    Month-4  Region - B  Manager - B           152167          231808
# 4    Month-5  Region - C  Manager - B           159525          258402
# 5    Month-6  Region - A  Manager - B           137163          256948
# 6    Month-7  Region - C  Manager - C           130625          222106
# 7    Month-8  Region - A  Manager - A           131140          230637
# 8    Month-9  Region - B  Manager - C           171259          226261
# 9   Month-10  Region - C  Manager - B           141956          193735
# 10  Month-11  Region - B  Manager - C           159339          203175
# 11  Month-12  Region - A  Manager - A           178939          276279
# ...

# %%
# Increase in Sales After Digital Marketing

# Perform a paired T-test to compare sales before and after digital marketing
sales_before = data2['Sales_Before_DM']
sales_after = data2['Sales_After_DM']
t_stat, p_value = ttest_rel(sales_before, sales_after)
p_value
# Out:
# 6.336667004575778e-11

# %%
print(f"Paired t-test results:\n t-statistic: {t_stat}\n p-value: {p_value}")
if p_value < 0.05:
    print("There is a significant increase in sales after stepping into digital marketing.")
else:
    print("There is no significant increase in sales after stepping into digital marketing.")
# Out:
# Paired t-test results:
#  t-statistic: -12.09070525287017
#  p-value: 6.336667004575778e-11
# There is a significant increase in sales after stepping into digital marketing.

# %%
# Dependency Between 'Region' and 'Manager'
# Create a contingency table and perform a Chi-squared test
tab_data = pd.crosstab(data2['Region'], data2['Manager'])
chi2stat, p_value, dof, exp = chi2_contingency(tab_data)
p_value
# Out:
# 0.5493991051158094

# %%
print(f"\nChi-squared test results:\nChi2-statistic: {chi2stat}\np-value: {p_value}")
if p_value < 0.05:
    print("There is a dependency between the features 'Region' and 'Manager'.")
else:
    print("There is no dependency between the features 'Region' and 'Manager'.")
# Out:
# Chi-squared test results:
# Chi2-statistic: 3.050566893424036
# p-value: 0.5493991051158094
# There is no dependency between the features 'Region' and 'Manager'.
